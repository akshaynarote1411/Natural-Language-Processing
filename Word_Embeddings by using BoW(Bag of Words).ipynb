# %%
from nltk.corpus import stopwords

sentences = ["Sky is nice", "Clouds are nice", "Sky is nice and Clouds are nice"]
cleaned_sentence = []

for sentence in sentences:
    word = sentence.lower()  # lowering all letters because we dont want it to treat uppercase and lowecase words differently.
    word = word.split()      # splitting our sentence into words
    
    word = [i for i in word if i not in set(stopwords.words("english"))]  # removing stopwords
    word = " ".join(word)          # joining our words back to sentences
    cleaned_sentence.append(word)  # appending our preprocessed sentences to a list
    
    
print(cleaned_sentence)
# Out:
# ['sky nice', 'clouds nice', 'sky nice clouds nice']

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features=3)   # give it a max features as 3
BagofWords = cv.fit_transform(cleaned_sentence)
                              
BagofWords   # BagofWords.toarray()
# Out:
# <3x3 sparse matrix of type '<class 'numpy.int64'>'
# 	with 7 stored elements in Compressed Sparse Row format>

# %%
BagofWords.toarray()
# Out:
# array([[0, 1, 1],
#        [1, 1, 0],
#        [1, 2, 1]], dtype=int64)

# %%
import pandas as pd
